# %%
# Data preparation
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Load data
Sales_df = pd.read_csv("preprocessed_data/sales.csv", index_col=0)
Ingredients_df = pd.read_csv("preprocessed_data/ingredients.csv", index_col=0)

# %%
Sales_df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
Sales_df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
Sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.8+ MB

# %%
Ingredients_df.isnull().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    0
# dtype: int64

# %%
# Parse dates function with error logging
def parse_dates(date):
    for fmt in ('%d-%m-%Y', '%d/%m/%Y', '%Y-%m-%d %H:%M:%S'):
        try:
            return pd.to_datetime(date, format=fmt)
        except ValueError:
            pass
    raise ValueError(f'No valid date format found for {date}')

# Apply the function to the 'order_date' column
Sales_df['order_date'] = Sales_df['order_date'].apply(parse_dates)

# %%
# Prepare data for weekly aggregation
Sales_df = Sales_df[['order_date', 'pizza_name', 'quantity']]
sales_summary = Sales_df.groupby(['order_date', 'pizza_name']).sum().reset_index()

# Pivot the data to have pizza names as columns
sales_pivot = sales_summary.pivot(index='order_date', columns='pizza_name', values='quantity').fillna(0)

# %%
sales_pivot.head()
# Out:
# pizza_name  The Barbecue Chicken Pizza  The Big Meat Pizza  \
# order_date
# 2015-01-01                        11.0                 5.0
# 2015-01-02                        12.0                 9.0
# 2015-01-03                         2.0                 3.0
# 2015-01-04                         2.0                 3.0
# 2015-01-05                         6.0                 1.0
#
# pizza_name  The Brie Carre Pizza  The Calabrese Pizza  \
# order_date
# 2015-01-01                   0.0                  1.0
# 2015-01-02                   3.0                  7.0
# 2015-01-03                   1.0                  1.0
# 2015-01-04                   0.0                  2.0
# 2015-01-05                   1.0                  4.0
#
# pizza_name  The California Chicken Pizza  The Chicken Alfredo Pizza  \
# order_date
# 2015-01-01                           4.0                        2.0
# 2015-01-02                          15.0                        3.0
# 2015-01-03                           6.0                        0.0
# 2015-01-04                           3.0                        3.0
# 2015-01-05                          11.0                        2.0
#
# pizza_name  The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# order_date
# 2015-01-01                      4.0                      10.0
# 2015-01-02                      2.0                      13.0
# 2015-01-03                      1.0                       4.0
# 2015-01-04                      2.0                       8.0
# 2015-01-05                      5.0                       9.0
#
# pizza_name  The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# order_date                                                ...
# 2015-01-01                    7.0                    6.0  ...
# 2015-01-02                    5.0                    6.0  ...
# 2015-01-03                    5.0                    4.0  ...
# 2015-01-04                    7.0                    6.0  ...
# 2015-01-05                    6.0                    4.0  ...
#
# pizza_name  The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# order_date
# 2015-01-01                               4.0                 4.0
# 2015-01-02                               6.0                 5.0
# 2015-01-03                               1.0                 2.0
# 2015-01-04                               4.0                 8.0
# 2015-01-05                               5.0                 5.0
#
# pizza_name  The Soppressata Pizza  The Southwest Chicken Pizza  \
# order_date
# 2015-01-01                    1.0                          7.0
# 2015-01-02                    3.0                          9.0
# 2015-01-03                    0.0                          9.0
# 2015-01-04                    6.0                         10.0
# 2015-01-05                    0.0                          6.0
#
# pizza_name  The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# order_date
# 2015-01-01                      5.0                      2.0
# 2015-01-02                      9.0                      5.0
# 2015-01-03                      4.0                      3.0
# 2015-01-04                      4.0                      4.0
# 2015-01-05                      5.0                      2.0
#
# pizza_name  The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# order_date
# 2015-01-01                        5.0                         2.0
# 2015-01-02                        3.0                         4.0
# 2015-01-03                        0.0                         5.0
# 2015-01-04                        6.0                         1.0
# 2015-01-05                        4.0                         5.0
#
# pizza_name  The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# order_date
# 2015-01-01                     8.0                                3.0
# 2015-01-02                     8.0                                1.0
# 2015-01-03                     4.0                                6.0
# 2015-01-04                     3.0                                5.0
# 2015-01-05                    10.0                                6.0
#
# [5 rows x 32 columns]

# %%
sales_summary.head()
# Out:
#   order_date                    pizza_name  quantity
# 0 2015-01-01    The Barbecue Chicken Pizza        11
# 1 2015-01-01            The Big Meat Pizza         5
# 2 2015-01-01           The Calabrese Pizza         1
# 3 2015-01-01  The California Chicken Pizza         4
# 4 2015-01-01     The Chicken Alfredo Pizza         2

# %%
Sales_df.tail()
# Out:
#       order_date                  pizza_name  quantity
# 48615 2015-12-31   The Chicken Alfredo Pizza         1
# 48616 2015-12-31       The Four Cheese Pizza         1
# 48617 2015-12-31        The Napolitana Pizza         1
# 48618 2015-12-31          The Mexicana Pizza         1
# 48619 2015-12-31  The Barbecue Chicken Pizza         1

# %%
# Applying SARIMA Model for Forecasting

# Initialize a dictionary to store SARIMA models for each pizza
sarima_models = {}

# Fit the SARIMA model for each pizza type
for pizza_name in sales_pivot.columns:
    try:
        model = SARIMAX(sales_pivot[pizza_name], order=(1, 1, 0), seasonal_order=(1, 1, 0, 7))
        model_fit = model.fit(disp=False)
        sarima_models[pizza_name] = model_fit
    except Exception as e:
        print(f"SARIMA model for {pizza_name} failed to fit.")
# Out:
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Generate Sales Forecast for Next Week (7 days)

prediction_days = 7

predictions_sarima = {}

# Generate forecast for the next 7 days for each pizza type
for pizza_name, model in sarima_models.items():
    predictions_sarima[pizza_name] = model.predict(start=len(sales_pivot), end=len(sales_pivot) + prediction_days - 1)

# Convert the predictions into a DataFrame
predictions_df = pd.DataFrame(predictions_sarima)

# Generate predicted dates
predicted_dates = pd.date_range(start=sales_pivot.index[-1] + pd.Timedelta(days=1), periods=prediction_days, freq='D')

# Assign predicted dates to predictions DataFrame
predictions_df.index = predicted_dates
# Out:
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\DELL\anaconda3\envs\py8\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
predictions_df.head()
# Out:
#             The Barbecue Chicken Pizza  The Big Meat Pizza  \
# 2016-01-01                    8.160714            3.027896
# 2016-01-02                    7.773062            7.377793
# 2016-01-03                    7.283069            4.185966
# 2016-01-04                    9.611882            3.542319
# 2016-01-05                    8.617341            5.322685
#
#             The Brie Carre Pizza  The Calabrese Pizza  \
# 2016-01-01              0.191648             2.268178
# 2016-01-02              0.865479             3.374618
# 2016-01-03              1.005429             2.077624
# 2016-01-04              0.125743             1.223214
# 2016-01-05              0.559086             3.652895
#
#             The California Chicken Pizza  The Chicken Alfredo Pizza  \
# 2016-01-01                      6.507168                   2.194045
# 2016-01-02                      6.495245                   3.052564
# 2016-01-03                      6.494081                   1.072046
# 2016-01-04                      6.504170                   2.943628
# 2016-01-05                      6.508639                   2.639193
#
#             The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# 2016-01-01                 3.389738                  7.393368
# 2016-01-02                 4.267490                  7.561603
# 2016-01-03                 2.997033                  7.445395
# 2016-01-04                 4.886369                  8.677715
# 2016-01-05                 1.682049                  6.206635
#
#             The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# 2016-01-01               3.948329               7.727451  ...
# 2016-01-02               3.641112              11.749415  ...
# 2016-01-03               3.195455              11.074673  ...
# 2016-01-04               2.043000               7.688107  ...
# 2016-01-05               2.455170               8.659632  ...
#
#             The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# 2016-01-01                          4.544626            0.634973
# 2016-01-02                          5.289952            0.803174
# 2016-01-03                          2.813993            2.336787
# 2016-01-04                          5.802684           -0.927236
# 2016-01-05                          3.670766           -0.218570
#
#             The Soppressata Pizza  The Southwest Chicken Pizza  \
# 2016-01-01               1.745454                     4.797908
# 2016-01-02               2.991464                     4.849589
# 2016-01-03               2.004835                     3.320830
# 2016-01-04               2.840617                     3.355027
# 2016-01-05               2.980137                     4.308192
#
#             The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# 2016-01-01                 2.419269                 4.851607
# 2016-01-02                 5.233762                 5.148542
# 2016-01-03                 5.127789                 5.581758
# 2016-01-04                 2.500047                 3.522347
# 2016-01-05                 3.009983                 4.824944
#
#             The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# 2016-01-01                   2.553220                    3.056631
# 2016-01-02                   3.993360                    2.522785
# 2016-01-03                   1.529954                    1.951653
# 2016-01-04                   3.018285                    4.209406
# 2016-01-05                   1.017486                    1.594424
#
#             The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# 2016-01-01                5.351353                           7.437561
# 2016-01-02                8.236196                           7.408238
# 2016-01-03                6.408649                          10.577717
# 2016-01-04                3.745625                           7.307964
# 2016-01-05                4.836520                           5.279084
#
# [5 rows x 32 columns]

# %%
ingredients_df = Ingredients_df[['pizza_name', 'pizza_ingredients', 'Items_Qty_In_Grams']]

# change column name to items_qty
ingredients_df.rename(columns={'Items_Qty_In_Grams': 'items_qty'}, inplace=True)
ingredients_df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20268\2376984744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingredients_df.rename(columns={'Items_Qty_In_Grams': 'items_qty'}, inplace=True)
#                             pizza_name  pizza_ingredients  items_qty
# 0           The Barbecue Chicken Pizza  Barbecued Chicken       40.0
# 1           The Barbecue Chicken Pizza        Red Peppers       15.0
# 2           The Barbecue Chicken Pizza      Green Peppers       20.0
# 3           The Barbecue Chicken Pizza           Tomatoes       30.0
# 4           The Barbecue Chicken Pizza         Red Onions       60.0
# ..                                 ...                ...        ...
# 513  The Vegetables + Vegetables Pizza      Green Peppers       20.0
# 514  The Vegetables + Vegetables Pizza         Red Onions       20.0
# 515  The Vegetables + Vegetables Pizza           Zucchini       10.0
# 516  The Vegetables + Vegetables Pizza            Spinach       15.0
# 517  The Vegetables + Vegetables Pizza             Garlic        5.0
#
# [518 rows x 3 columns]

# %%
# Create a dictionary to store ingredient quantities
ingredient_quantities = {}

# Get the ingredients for the pizza
for pizza_name in predictions_df.columns:
    predicted_quantity = predictions_df[pizza_name].sum()
    pizza_ingredients = ingredients_df[ingredients_df['pizza_name'] == pizza_name]
    
    for index, row in pizza_ingredients.iterrows():
        ingredient = row['pizza_ingredients']
        ingredient_qty = row['items_qty']
        required_quantity = predicted_quantity * ingredient_qty
        
        # Add to the dictionary
        if ingredient in ingredient_quantities:
            ingredient_quantities[ingredient] += required_quantity
        else:
            ingredient_quantities[ingredient] = required_quantity

# %%
# Create a DataFrame from the ingredient quantities
ingredient_requirements_df = pd.DataFrame.from_dict(ingredient_quantities, orient='index', columns=['required_quantity'])
ingredient_requirements_df
# Out:
#                          required_quantity
# Barbecued Chicken              5554.579650
# Red Peppers                   11192.015949
# Green Peppers                  7683.637506
# Tomatoes                      29914.962419
# Red Onions                    44887.814993
# ...                                    ...
# Luganega Sausage                445.626231
# Onions                          222.813116
# Soppressata Salami             5304.511970
# Peperoncini verdi               917.818086
# Thai Sweet Chilli Sauce        2147.966446
#
# [64 rows x 1 columns]

# %%
# Determine the last date in historical data
last_date = sales_pivot.index[-1]

# Generate date range for predictions
prediction_days = 7  # Number of days to predict
predicted_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=prediction_days, freq='D')

# Assign predicted dates to predictions DataFrame
predictions_df.index = predicted_dates
predictions_df
# Out:
#             The Barbecue Chicken Pizza  The Big Meat Pizza  \
# 2016-01-01                    8.160714            3.027896
# 2016-01-02                    7.773062            7.377793
# 2016-01-03                    7.283069            4.185966
# 2016-01-04                    9.611882            3.542319
# 2016-01-05                    8.617341            5.322685
# 2016-01-06                    8.561071            5.052242
# 2016-01-07                   11.710412            5.363211
#
#             The Brie Carre Pizza  The Calabrese Pizza  \
# 2016-01-01              0.191648             2.268178
# 2016-01-02              0.865479             3.374618
# 2016-01-03              1.005429             2.077624
# 2016-01-04              0.125743             1.223214
# 2016-01-05              0.559086             3.652895
# 2016-01-06             -0.380149             1.688557
# 2016-01-07              1.587643             2.167527
#
#             The California Chicken Pizza  The Chicken Alfredo Pizza  \
# 2016-01-01                      6.507168                   2.194045
# 2016-01-02                      6.495245                   3.052564
# 2016-01-03                      6.494081                   1.072046
# 2016-01-04                      6.504170                   2.943628
# 2016-01-05                      6.508639                   2.639193
# 2016-01-06                      7.011159                   2.731303
# 2016-01-07                      6.015844                   3.524026
#
#             The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# 2016-01-01                 3.389738                  7.393368
# 2016-01-02                 4.267490                  7.561603
# 2016-01-03                 2.997033                  7.445395
# 2016-01-04                 4.886369                  8.677715
# 2016-01-05                 1.682049                  6.206635
# 2016-01-06                 2.341016                  5.180927
# 2016-01-07                 3.658955                  9.071744
#
#             The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# 2016-01-01               3.948329               7.727451  ...
# 2016-01-02               3.641112              11.749415  ...
# 2016-01-03               3.195455              11.074673  ...
# 2016-01-04               2.043000               7.688107  ...
# 2016-01-05               2.455170               8.659632  ...
# 2016-01-06               2.372682              11.341155  ...
# 2016-01-07               4.949138               8.608578  ...
#
#             The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# 2016-01-01                          4.544626            0.634973
# 2016-01-02                          5.289952            0.803174
# 2016-01-03                          2.813993            2.336787
# 2016-01-04                          5.802684           -0.927236
# 2016-01-05                          3.670766           -0.218570
# 2016-01-06                          3.160844           -2.229550
# 2016-01-07                          5.283026            3.313974
#
#             The Soppressata Pizza  The Southwest Chicken Pizza  \
# 2016-01-01               1.745454                     4.797908
# 2016-01-02               2.991464                     4.849589
# 2016-01-03               2.004835                     3.320830
# 2016-01-04               2.840617                     3.355027
# 2016-01-05               2.980137                     4.308192
# 2016-01-06               2.120870                     6.361716
# 2016-01-07               2.998330                     5.841193
#
#             The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# 2016-01-01                 2.419269                 4.851607
# 2016-01-02                 5.233762                 5.148542
# 2016-01-03                 5.127789                 5.581758
# 2016-01-04                 2.500047                 3.522347
# 2016-01-05                 3.009983                 4.824944
# 2016-01-06                 4.504393                 4.707990
# 2016-01-07                 7.798694                 5.231970
#
#             The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# 2016-01-01                   2.553220                    3.056631
# 2016-01-02                   3.993360                    2.522785
# 2016-01-03                   1.529954                    1.951653
# 2016-01-04                   3.018285                    4.209406
# 2016-01-05                   1.017486                    1.594424
# 2016-01-06                   2.044443                    1.660103
# 2016-01-07                   1.557527                    4.172336
#
#             The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# 2016-01-01                5.351353                           7.437561
# 2016-01-02                8.236196                           7.408238
# 2016-01-03                6.408649                          10.577717
# 2016-01-04                3.745625                           7.307964
# 2016-01-05                4.836520                           5.279084
# 2016-01-06                3.349258                           7.517579
# 2016-01-07                3.871841                          11.625989
#
# [7 rows x 32 columns]

# %%
# Create a purchase order DataFrame
purchase_order_df = ingredient_requirements_df.copy()

# Add a column for the unit of measure (assuming all ingredients are in grams)
purchase_order_df['unit'] = 'grams'

# Rename the columns for better readability
purchase_order_df = purchase_order_df.rename(columns={'required_quantity': 'quantity'})

# Add a header to the purchase order
print('Purchase Order:')
# print('----------------')

# Print the purchase order table
print(purchase_order_df.to_string())
# Out:
# Purchase Order:
#                                 quantity   unit
# Barbecued Chicken            5554.579650  grams
# Red Peppers                 11192.015949  grams
# Green Peppers                7683.637506  grams
# Tomatoes                    29914.962419  grams
# Red Onions                  44887.814993  grams
# Barbecue Sauce               1851.526550  grams
# Bacon                       18995.910759  grams
# Pepperoni                   22477.214206  grams
# Italian Sausage               338.721110  grams
# Chorizo Sausage              1693.605548  grams
# Brie Carre Cheese             118.646399  grams
# Prosciutto                    118.646399  grams
# Caramelized Onions             63.278080  grams
# Pears                          39.548800  grams
# Thyme                          19.774400  grams
# Garlic                      15418.184086  grams
# ?duja Salami                 1974.313619  grams
# Pancetta                     2961.470428  grams
# Friggitello Peppers           493.578405  grams
# Chicken                     46664.897312  grams
# Artichokes                   7036.394758  grams
# Spinach                     19257.316443  grams
# Jalapeno Peppers             3207.003938  grams
# Fontina Cheese               3793.080752  grams
# Gouda Cheese                 2732.178358  grams
# Mushrooms                   22664.931027  grams
# Asiago Cheese                3992.993181  grams
# Alfredo Sauce                 817.056245  grams
# Pesto Sauce                  4366.942794  grams
# Mozzarella Cheese           10005.275338  grams
# Provolone Cheese              678.146631  grams
# Smoked Gouda Cheese           678.146631  grams
# Romano Cheese                 678.146631  grams
# Blue Cheese                   678.146631  grams
# Ricotta Cheese               5013.675884  grams
# Gorgonzola Piccante Cheese   4010.940707  grams
# Parmigiano Reggiano Cheese  10027.351768  grams
# Kalamata Olives               375.553816  grams
# Feta Cheese                  1168.060951  grams
# Beef Chuck Roast            -4139.544287  grams
# Green Olives                 2521.704188  grams
# Sliced Ham                   1600.844039  grams
# Pineapple                    5142.962515  grams
# Capocollo                   44902.400272  grams
# Goat Cheese                  9482.252778  grams
# Oregano                      1452.745109  grams
# Calabrese Salami            11393.126694  grams
# Eggplant                     1882.868447  grams
# Zucchini                     4370.682116  grams
# Sun-dried Tomatoes           1464.877198  grams
# Plum Tomatoes                1795.209728  grams
# Cilantro                     1840.914759  grams
# Corn                        12272.765059  grams
# Chipotle Sauce               3681.829518  grams
# Anchovies                    3231.693565  grams
# Genoa Salami                 5882.184980  grams
# Prosciutto di San Daniele    2139.612304  grams
# Arugula                       916.976702  grams
# Coarse Sicilian Salami        891.252463  grams
# Luganega Sausage              445.626231  grams
# Onions                        222.813116  grams
# Soppressata Salami           5304.511970  grams
# Peperoncini verdi             917.818086  grams
# Thai Sweet Chilli Sauce      2147.966446  grams

# %%
# purchase_order_df.to_csv("purchase_order.txt")
